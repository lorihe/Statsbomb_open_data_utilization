# %%
import requests
import json
import pandas as pd
import urllib.request

import soccerfield

import dash
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = 'notebook'

import warnings
warnings.filterwarnings('ignore')
# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
def load_json(url):
    response = requests.get(url)
    return response.json()

# %%
url_WC_2023 = 'https://raw.githubusercontent.com/statsbomb/open-data/master/data/matches/72/107.json'
json_data_2023 = load_json(url_WC_2023)

# %%
url_WC_2022 = 'https://raw.githubusercontent.com/statsbomb/open-data/master/data/matches/43/106.json'
json_data_2022 = load_json(url_WC_2022)

# %%
json_data_2023
# Out:
# [{'match_id': 3904629,
#   'match_date': '2023-08-16',
#   'kick_off': '13:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1205,
#    'home_team_name': "Australia Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 14, 'name': 'Australia'},
#    'managers': [{'id': 408,
#      'name': 'Tony Gustavsson',
#      'nickname': None,
#      'dob': '1973-08-14',
#      'country': {'id': 220, 'name': 'Sweden'}}]},
#   'away_team': {'away_team_id': 865,
#    'away_team_name': "England Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 45,
#      'name': 'Sarina Glotzbach-Wiegman',
#      'nickname': 'Sarina Wiegman',
#      'dob': '1969-10-26',
#      'country': {'id': 160, 'name': 'Netherlands'}}]},
#   'home_score': 1,
#   'away_score': 3,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-22T06:06:44.749511',
#   'last_updated_360': '2023-08-22T06:09:59.590032',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 6,
#   'competition_stage': {'id': 15, 'name': 'Semi-finals'},
#   'stadium': {'id': 117593,
#    'name': 'Accor Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 1171,
#    'name': 'Tori Penso',
#    'country': {'id': 241, 'name': 'United States of America'}}},
#  {'match_id': 3906390,
#   'match_date': '2023-08-20',
#   'kick_off': '13:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 863,
#    'home_team_name': "Spain Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 214, 'name': 'Spain'},
#    'managers': [{'id': 418,
#      'name': 'Jorge Vilda',
#      'nickname': None,
#      'dob': '1981-07-07',
#      'country': {'id': 214, 'name': 'Spain'}}]},
#   'away_team': {'away_team_id': 865,
#    'away_team_name': "England Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 45,
#      'name': 'Sarina Glotzbach-Wiegman',
#      'nickname': 'Sarina Wiegman',
#      'dob': '1969-10-26',
#      'country': {'id': 160, 'name': 'Netherlands'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-22T19:29:29.948278',
#   'last_updated_360': '2023-08-22T19:38:43.965521',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 7,
#   'competition_stage': {'id': 26, 'name': 'Final'},
#   'stadium': {'id': 117593,
#    'name': 'Accor Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 1171,
#    'name': 'Tori Penso',
#    'country': {'id': 241, 'name': 'United States of America'}}},
#  {'match_id': 3906389,
#   'match_date': '2023-08-19',
#   'kick_off': '11:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 858,
#    'home_team_name': "Sweden Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 220, 'name': 'Sweden'},
#    'managers': [{'id': 3016,
#      'name': 'Peter Gerhardsson',
#      'nickname': None,
#      'dob': '1959-08-22',
#      'country': {'id': 220, 'name': 'Sweden'}}]},
#   'away_team': {'away_team_id': 1205,
#    'away_team_name': "Australia Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 14, 'name': 'Australia'},
#    'managers': [{'id': 408,
#      'name': 'Tony Gustavsson',
#      'nickname': None,
#      'dob': '1973-08-14',
#      'country': {'id': 220, 'name': 'Sweden'}}]},
#   'home_score': 2,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-20T09:48:54.999694',
#   'last_updated_360': '2023-08-20T16:49:17.843380',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 7,
#   'competition_stage': {'id': 25, 'name': '3rd Place Final'},
#   'stadium': {'id': 28884,
#    'name': 'Brisbane Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 833,
#    'name': 'Cheryl Foster',
#    'country': {'id': 249, 'name': 'Wales'}}},
#  {'match_id': 3904628,
#   'match_date': '2023-08-15',
#   'kick_off': '11:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 863,
#    'home_team_name': "Spain Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 214, 'name': 'Spain'},
#    'managers': [{'id': 418,
#      'name': 'Jorge Vilda',
#      'nickname': None,
#      'dob': '1981-07-07',
#      'country': {'id': 214, 'name': 'Spain'}}]},
#   'away_team': {'away_team_id': 858,
#    'away_team_name': "Sweden Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 220, 'name': 'Sweden'},
#    'managers': [{'id': 3016,
#      'name': 'Peter Gerhardsson',
#      'nickname': None,
#      'dob': '1959-08-22',
#      'country': {'id': 220, 'name': 'Sweden'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-16T03:41:23.763496',
#   'last_updated_360': '2023-08-16T11:30:31.556462',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 6,
#   'competition_stage': {'id': 15, 'name': 'Semi-finals'},
#   'stadium': {'id': 28892,
#    'name': 'Eden Park',
#    'country': {'id': 163, 'name': 'New Zealand'}},
#   'referee': {'id': 2426,
#    'name': 'Edina Alves Batista',
#    'country': {'id': 31, 'name': 'Brazil'}}},
#  {'match_id': 3893806,
#   'match_date': '2023-07-26',
#   'kick_off': '10:30:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 863,
#    'home_team_name': "Spain Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 214, 'name': 'Spain'},
#    'managers': [{'id': 418,
#      'name': 'Jorge Vilda',
#      'nickname': None,
#      'dob': '1981-07-07',
#      'country': {'id': 214, 'name': 'Spain'}}]},
#   'away_team': {'away_team_id': 6045,
#    'away_team_name': "Zambia Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 253, 'name': 'Zambia'},
#    'managers': [{'id': 1000425,
#      'name': 'Bruce Mwape',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 253, 'name': 'Zambia'}}]},
#   'home_score': 5,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-15T02:56:48.548242',
#   'last_updated_360': '2023-08-15T02:58:57.266594',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 28892,
#    'name': 'Eden Park',
#    'country': {'id': 163, 'name': 'New Zealand'}},
#   'referee': {'id': 1006261,
#    'name': 'Hyeon-Jeong Oh',
#    'country': {'id': 121, 'name': 'Korea\xa0(South)'}}},
#  {'match_id': 3893801,
#   'match_date': '2023-07-24',
#   'kick_off': '14:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1203,
#    'home_team_name': "Brazil Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 31, 'name': 'Brazil'},
#    'managers': [{'id': 177,
#      'name': 'Pia Mariane Sundhage',
#      'nickname': 'Pia Sundhage',
#      'dob': '1960-02-13',
#      'country': {'id': 220, 'name': 'Sweden'}}]},
#   'away_team': {'away_team_id': 16803,
#    'away_team_name': "Panama Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 176, 'name': 'Panama'},
#    'managers': [{'id': 1003446,
#      'name': 'Ignacio Quintana Toledo',
#      'nickname': None,
#      'dob': '1988-04-20',
#      'country': {'id': 147, 'name': 'Mexico'}}]},
#   'home_score': 4,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-15T03:16:13.146076',
#   'last_updated_360': '2023-08-15T03:18:08.766850',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 1,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 28889,
#    'name': 'Coopers Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 833,
#    'name': 'Cheryl Foster',
#    'country': {'id': 249, 'name': 'Wales'}}},
#  {'match_id': 3893797,
#   'match_date': '2023-07-23',
#   'kick_off': '10:30:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 851,
#    'home_team_name': "Netherlands Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 160, 'name': 'Netherlands'},
#    'managers': [{'id': 46,
#      'name': 'Andries Jonker',
#      'nickname': None,
#      'dob': '1962-09-22',
#      'country': {'id': 160, 'name': 'Netherlands'}}]},
#   'away_team': {'away_team_id': 864,
#    'away_team_name': "Portugal Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 183, 'name': 'Portugal'},
#    'managers': [{'id': 419,
#      'name': 'Francisco Miguel Conceição Roque Neto',
#      'nickname': 'Francisco Neto',
#      'dob': '1981-07-11',
#      'country': {'id': 183, 'name': 'Portugal'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-15T02:38:46.816155',
#   'last_updated_360': '2023-08-15T02:40:19.749196',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 1,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 1001341,
#    'name': 'Forsyth Barr',
#    'country': {'id': 163, 'name': 'New Zealand'}}},
#  {'match_id': 3893822,
#   'match_date': '2023-07-31',
#   'kick_off': '10:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1210,
#    'home_team_name': "Japan Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 114, 'name': 'Japan'},
#    'managers': [{'id': 1003258,
#      'name': 'Futoshi Ikeda',
#      'nickname': None,
#      'dob': '1970-10-04',
#      'country': {'id': 114, 'name': 'Japan'}}]},
#   'away_team': {'away_team_id': 863,
#    'away_team_name': "Spain Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 214, 'name': 'Spain'},
#    'managers': [{'id': 418,
#      'name': 'Jorge Vilda',
#      'nickname': None,
#      'dob': '1981-07-07',
#      'country': {'id': 214, 'name': 'Spain'}}]},
#   'home_score': 4,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-15T03:17:41.945052',
#   'last_updated_360': '2023-08-15T03:20:22.749909',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 3,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 98115,
#    'name': 'Wellington Regional Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 751,
#    'name': 'Katja Koroleva',
#    'country': {'id': 241, 'name': 'United States of America'}}},
#  {'match_id': 3893814,
#   'match_date': '2023-07-29',
#   'kick_off': '10:30:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 858,
#    'home_team_name': "Sweden Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 220, 'name': 'Sweden'},
#    'managers': [{'id': 3016,
#      'name': 'Peter Gerhardsson',
#      'nickname': None,
#      'dob': '1959-08-22',
#      'country': {'id': 220, 'name': 'Sweden'}}]},
#   'away_team': {'away_team_id': 855,
#    'away_team_name': "Italy Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 112, 'name': 'Italy'},
#    'managers': [{'id': 4085,
#      'name': 'Milena Bertolini',
#      'nickname': None,
#      'dob': '1966-06-24',
#      'country': {'id': 112, 'name': 'Italy'}}]},
#   'home_score': 5,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-15T02:40:01.211524',
#   'last_updated_360': '2023-08-15T02:40:42.886046',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 98115,
#    'name': 'Wellington Regional Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 833,
#    'name': 'Cheryl Foster',
#    'country': {'id': 249, 'name': 'Wales'}}},
#  {'match_id': 3893790,
#   'match_date': '2023-07-21',
#   'kick_off': '05:30:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1213,
#    'home_team_name': "Nigeria Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 166, 'name': 'Nigeria'},
#    'managers': [{'id': 1003417,
#      'name': 'Randy Marlon Waldrum',
#      'nickname': None,
#      'dob': '1956-09-25',
#      'country': {'id': 241, 'name': 'United States of America'}}]},
#   'away_team': {'away_team_id': 1206,
#    'away_team_name': "Canada Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 40, 'name': 'Canada'},
#    'managers': [{'id': 1000081,
#      'name': 'Beverly Priestman',
#      'nickname': None,
#      'dob': '1986-04-29',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-15T01:27:08.890984',
#   'last_updated_360': '2023-08-15T01:27:44.637065',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 1,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 28886,
#    'name': 'AAMI Park',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 965,
#    'name': 'Lina Lehtovaara',
#    'country': {'id': 77, 'name': 'Finland'}}},
#  {'match_id': 3901832,
#   'match_date': '2023-08-08',
#   'kick_off': '11:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 16802,
#    'home_team_name': "Colombia Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 49, 'name': 'Colombia'},
#    'managers': [{'id': 1003448,
#      'name': 'Nelson Abadía Aragón',
#      'nickname': None,
#      'dob': '1956-06-05',
#      'country': {'id': 49, 'name': 'Colombia'}}]},
#   'away_team': {'away_team_id': 1212,
#    'away_team_name': "Jamaica Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 113, 'name': 'Jamaica'},
#    'managers': [{'id': 1003439,
#      'name': 'Lorne Julian Donaldson',
#      'nickname': None,
#      'dob': '1986-10-09',
#      'country': {'id': 241, 'name': 'United States of America'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-22T16:38:42.515802',
#   'last_updated_360': '2023-08-22T16:48:17.037772',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 4,
#   'competition_stage': {'id': 33, 'name': 'Round of 16'},
#   'stadium': {'id': 28886,
#    'name': 'AAMI Park',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 1640,
#    'name': 'Kate Jacewicz',
#    'country': {'id': 14, 'name': 'Australia'}}},
#  {'match_id': 3902968,
#   'match_date': '2023-08-12',
#   'kick_off': '10:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1205,
#    'home_team_name': "Australia Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 14, 'name': 'Australia'},
#    'managers': [{'id': 408,
#      'name': 'Tony Gustavsson',
#      'nickname': None,
#      'dob': '1973-08-14',
#      'country': {'id': 220, 'name': 'Sweden'}}]},
#   'away_team': {'away_team_id': 861,
#    'away_team_name': "France Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 78, 'name': 'France'},
#    'managers': [{'id': 642,
#      'name': 'Hervé Renard',
#      'nickname': None,
#      'dob': '1968-09-30',
#      'country': {'id': 78, 'name': 'France'}}]},
#   'home_score': 0,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-14T17:02:33.842702',
#   'last_updated_360': '2023-08-14T17:07:49.221838',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 5,
#   'competition_stage': {'id': 11, 'name': 'Quarter-finals'},
#   'stadium': {'id': 28884,
#    'name': 'Brisbane Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 2476,
#    'name': 'María Belén Carvajal Peña',
#    'country': {'id': 45, 'name': 'Chile'}}},
#  {'match_id': 3902967,
#   'match_date': '2023-08-12',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 865,
#    'home_team_name': "England Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 45,
#      'name': 'Sarina Glotzbach-Wiegman',
#      'nickname': 'Sarina Wiegman',
#      'dob': '1969-10-26',
#      'country': {'id': 160, 'name': 'Netherlands'}}]},
#   'away_team': {'away_team_id': 16802,
#    'away_team_name': "Colombia Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 49, 'name': 'Colombia'},
#    'managers': [{'id': 1003448,
#      'name': 'Nelson Abadía Aragón',
#      'nickname': None,
#      'dob': '1956-06-05',
#      'country': {'id': 49, 'name': 'Colombia'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-13T22:22:55.575995',
#   'last_updated_360': '2023-08-13T22:25:58.459948',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 5,
#   'competition_stage': {'id': 11, 'name': 'Quarter-finals'},
#   'stadium': {'id': 117593,
#    'name': 'Accor Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 751,
#    'name': 'Katja Koroleva',
#    'country': {'id': 241, 'name': 'United States of America'}}},
#  {'match_id': 3901797,
#   'match_date': '2023-08-06',
#   'kick_off': '12:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 858,
#    'home_team_name': "Sweden Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 220, 'name': 'Sweden'},
#    'managers': [{'id': 3016,
#      'name': 'Peter Gerhardsson',
#      'nickname': None,
#      'dob': '1959-08-22',
#      'country': {'id': 220, 'name': 'Sweden'}}]},
#   'away_team': {'away_team_id': 1214,
#    'away_team_name': "United States Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 241, 'name': 'United States of America'},
#    'managers': [{'id': 141,
#      'name': 'Vlatko Andonovski',
#      'nickname': None,
#      'dob': '1976-09-14',
#      'country': {'id': 241, 'name': 'United States of America'}}]},
#   'home_score': 0,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-19T09:34:46.784444',
#   'last_updated_360': '2023-08-19T09:38:22.452882',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 4,
#   'competition_stage': {'id': 33, 'name': 'Round of 16'},
#   'stadium': {'id': 28886,
#    'name': 'AAMI Park',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 128,
#    'name': 'Stéphanie Frappart',
#    'country': {'id': 78, 'name': 'France'}}},
#  {'match_id': 3901796,
#   'match_date': '2023-08-06',
#   'kick_off': '05:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 851,
#    'home_team_name': "Netherlands Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 160, 'name': 'Netherlands'},
#    'managers': [{'id': 46,
#      'name': 'Andries Jonker',
#      'nickname': None,
#      'dob': '1962-09-22',
#      'country': {'id': 160, 'name': 'Netherlands'}}]},
#   'away_team': {'away_team_id': 1216,
#    'away_team_name': "South Africa Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 211, 'name': 'South Africa'},
#    'managers': [{'id': 3925,
#      'name': 'Desiree Ellis',
#      'nickname': None,
#      'dob': '1963-03-14',
#      'country': {'id': 211, 'name': 'South Africa'}}]},
#   'home_score': 2,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-07T07:10:53.729932',
#   'last_updated_360': '2023-08-07T21:56:45.627086',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 4,
#   'competition_stage': {'id': 33, 'name': 'Round of 16'},
#   'stadium': {'id': 1001126,
#    'name': 'Allianz Stadium (Sydney)',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 2546,
#    'name': 'Yoshimi Yamashita',
#    'country': {'id': 114, 'name': 'Japan'}}},
#  {'match_id': 3902240,
#   'match_date': '2023-08-11',
#   'kick_off': '04:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 863,
#    'home_team_name': "Spain Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 214, 'name': 'Spain'},
#    'managers': [{'id': 418,
#      'name': 'Jorge Vilda',
#      'nickname': None,
#      'dob': '1981-07-07',
#      'country': {'id': 214, 'name': 'Spain'}}]},
#   'away_team': {'away_team_id': 851,
#    'away_team_name': "Netherlands Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 160, 'name': 'Netherlands'},
#    'managers': [{'id': 46,
#      'name': 'Andries Jonker',
#      'nickname': None,
#      'dob': '1962-09-22',
#      'country': {'id': 160, 'name': 'Netherlands'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-12T12:10:27.546657',
#   'last_updated_360': '2023-08-14T09:22:25.109084',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 5,
#   'competition_stage': {'id': 11, 'name': 'Quarter-finals'},
#   'stadium': {'id': 98115,
#    'name': 'Wellington Regional Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 128,
#    'name': 'Stéphanie Frappart',
#    'country': {'id': 78, 'name': 'France'}}},
#  {'match_id': 3902239,
#   'match_date': '2023-08-11',
#   'kick_off': '10:30:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1210,
#    'home_team_name': "Japan Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 114, 'name': 'Japan'},
#    'managers': [{'id': 1003258,
#      'name': 'Futoshi Ikeda',
#      'nickname': None,
#      'dob': '1970-10-04',
#      'country': {'id': 114, 'name': 'Japan'}}]},
#   'away_team': {'away_team_id': 858,
#    'away_team_name': "Sweden Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 220, 'name': 'Sweden'},
#    'managers': [{'id': 3016,
#      'name': 'Peter Gerhardsson',
#      'nickname': None,
#      'dob': '1959-08-22',
#      'country': {'id': 220, 'name': 'Sweden'}}]},
#   'home_score': 1,
#   'away_score': 2,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-17T01:22:31.673432',
#   'last_updated_360': '2023-08-17T01:23:56.292576',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 5,
#   'competition_stage': {'id': 11, 'name': 'Quarter-finals'},
#   'stadium': {'id': 28892,
#    'name': 'Eden Park',
#    'country': {'id': 163, 'name': 'New Zealand'}},
#   'referee': {'id': 723,
#    'name': 'Esther Staubli',
#    'country': {'id': 221, 'name': 'Switzerland'}}},
#  {'match_id': 3893808,
#   'match_date': '2023-07-27',
#   'kick_off': '04:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1214,
#    'home_team_name': "United States Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 241, 'name': 'United States of America'},
#    'managers': [{'id': 141,
#      'name': 'Vlatko Andonovski',
#      'nickname': None,
#      'dob': '1976-09-14',
#      'country': {'id': 241, 'name': 'United States of America'}}]},
#   'away_team': {'away_team_id': 851,
#    'away_team_name': "Netherlands Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 160, 'name': 'Netherlands'},
#    'managers': [{'id': 46,
#      'name': 'Andries Jonker',
#      'nickname': None,
#      'dob': '1962-09-22',
#      'country': {'id': 160, 'name': 'Netherlands'}}]},
#   'home_score': 1,
#   'away_score': 1,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-03T18:01:52.417007',
#   'last_updated_360': '2023-08-03T18:02:47.350984',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 98115,
#    'name': 'Wellington Regional Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 2546,
#    'name': 'Yoshimi Yamashita',
#    'country': {'id': 114, 'name': 'Japan'}}},
#  {'match_id': 3901833,
#   'match_date': '2023-08-08',
#   'kick_off': '14:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 861,
#    'home_team_name': "France Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 78, 'name': 'France'},
#    'managers': [{'id': 642,
#      'name': 'Hervé Renard',
#      'nickname': None,
#      'dob': '1968-09-30',
#      'country': {'id': 78, 'name': 'France'}}]},
#   'away_team': {'away_team_id': 2391,
#    'away_team_name': "Morocco Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 154, 'name': 'Morocco'},
#    'managers': [{'id': 760,
#      'name': 'Reynald Pedros',
#      'nickname': None,
#      'dob': '1971-10-10',
#      'country': {'id': 78, 'name': 'France'}}]},
#   'home_score': 4,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-09T06:50:05.452016',
#   'last_updated_360': '2023-08-09T16:38:59.260536',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 4,
#   'competition_stage': {'id': 33, 'name': 'Round of 16'},
#   'stadium': {'id': 28889,
#    'name': 'Coopers Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 1171,
#    'name': 'Tori Penso',
#    'country': {'id': 241, 'name': 'United States of America'}}},
#  {'match_id': 3893826,
#   'match_date': '2023-08-01',
#   'kick_off': '10:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 864,
#    'home_team_name': "Portugal Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 183, 'name': 'Portugal'},
#    'managers': [{'id': 419,
#      'name': 'Francisco Miguel Conceição Roque Neto',
#      'nickname': 'Francisco Neto',
#      'dob': '1981-07-11',
#      'country': {'id': 183, 'name': 'Portugal'}}]},
#   'away_team': {'away_team_id': 1214,
#    'away_team_name': "United States Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 241, 'name': 'United States of America'},
#    'managers': [{'id': 141,
#      'name': 'Vlatko Andonovski',
#      'nickname': None,
#      'dob': '1976-09-14',
#      'country': {'id': 241, 'name': 'United States of America'}}]},
#   'home_score': 0,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-18T17:13:09.924522',
#   'last_updated_360': '2023-08-18T17:15:26.138057',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 3,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 28892,
#    'name': 'Eden Park',
#    'country': {'id': 163, 'name': 'New Zealand'}},
#   'referee': {'id': 566,
#    'name': 'Rebecca Welch',
#    'country': {'id': 68, 'name': 'England'}}},
#  {'match_id': 3901736,
#   'match_date': '2023-08-07',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1205,
#    'home_team_name': "Australia Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 14, 'name': 'Australia'},
#    'managers': [{'id': 408,
#      'name': 'Tony Gustavsson',
#      'nickname': None,
#      'dob': '1973-08-14',
#      'country': {'id': 220, 'name': 'Sweden'}}]},
#   'away_team': {'away_team_id': 853,
#    'away_team_name': "Denmark Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 61, 'name': 'Denmark'},
#    'managers': [{'id': 3574,
#      'name': 'Lars Søndergaard',
#      'nickname': None,
#      'dob': '1959-04-05',
#      'country': {'id': 61, 'name': 'Denmark'}}]},
#   'home_score': 2,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-22T21:01:33.702562',
#   'last_updated_360': '2023-08-22T21:04:15.132891',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 4,
#   'competition_stage': {'id': 33, 'name': 'Round of 16'},
#   'stadium': {'id': 1000938,
#    'name': 'Stadium Australia',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 566,
#    'name': 'Rebecca Welch',
#    'country': {'id': 68, 'name': 'England'}}},
#  {'match_id': 3901734,
#   'match_date': '2023-08-05',
#   'kick_off': '11:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1210,
#    'home_team_name': "Japan Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 114, 'name': 'Japan'},
#    'managers': [{'id': 1003258,
#      'name': 'Futoshi Ikeda',
#      'nickname': None,
#      'dob': '1970-10-04',
#      'country': {'id': 114, 'name': 'Japan'}}]},
#   'away_team': {'away_team_id': 852,
#    'away_team_name': "Norway Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 171, 'name': 'Norway'},
#    'managers': [{'id': 1769,
#      'name': 'Hege Riise',
#      'nickname': None,
#      'dob': '1969-07-18',
#      'country': {'id': 171, 'name': 'Norway'}}]},
#   'home_score': 3,
#   'away_score': 1,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-07T18:22:51.079828',
#   'last_updated_360': '2023-08-08T10:15:46.456421',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 4,
#   'competition_stage': {'id': 33, 'name': 'Round of 16'},
#   'stadium': {'id': 98115,
#    'name': 'Wellington Regional Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 2426,
#    'name': 'Edina Alves Batista',
#    'country': {'id': 31, 'name': 'Brazil'}}},
#  {'match_id': 3901733,
#   'match_date': '2023-08-05',
#   'kick_off': '08:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 860,
#    'home_team_name': "Switzerland Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 221, 'name': 'Switzerland'},
#    'managers': [{'id': 1002252,
#      'name': 'Inka Grings',
#      'nickname': None,
#      'dob': '1978-10-31',
#      'country': {'id': 85, 'name': 'Germany'}}]},
#   'away_team': {'away_team_id': 863,
#    'away_team_name': "Spain Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 214, 'name': 'Spain'},
#    'managers': [{'id': 418,
#      'name': 'Jorge Vilda',
#      'nickname': None,
#      'dob': '1981-07-07',
#      'country': {'id': 214, 'name': 'Spain'}}]},
#   'home_score': 1,
#   'away_score': 5,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-18T14:50:59.575701',
#   'last_updated_360': '2023-08-18T14:52:21.788300',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 4,
#   'competition_stage': {'id': 33, 'name': 'Round of 16'},
#   'stadium': {'id': 28892,
#    'name': 'Eden Park',
#    'country': {'id': 163, 'name': 'New Zealand'}},
#   'referee': {'id': 833,
#    'name': 'Cheryl Foster',
#    'country': {'id': 249, 'name': 'Wales'}}},
#  {'match_id': 3893823,
#   'match_date': '2023-07-31',
#   'kick_off': '10:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1832,
#    'home_team_name': "Costa Rica Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 54, 'name': 'Costa Rica'},
#    'managers': [{'id': 4855,
#      'name': 'Amelia Valverde',
#      'nickname': None,
#      'dob': '1987-01-14',
#      'country': {'id': 54, 'name': 'Costa Rica'}}]},
#   'away_team': {'away_team_id': 6045,
#    'away_team_name': "Zambia Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 253, 'name': 'Zambia'},
#    'managers': [{'id': 1000425,
#      'name': 'Bruce Mwape',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 253, 'name': 'Zambia'}}]},
#   'home_score': 1,
#   'away_score': 3,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-21T13:22:23.108775',
#   'last_updated_360': '2023-08-21T13:33:01.795',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 3,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 1001342,
#    'name': 'FMG Stadium Waikato',
#    'country': {'id': 163, 'name': 'New Zealand'}},
#   'referee': {'id': 1005493,
#    'name': 'Bouchra Karboubi',
#    'country': {'id': 154, 'name': 'Morocco'}}},
#  {'match_id': 3893811,
#   'match_date': '2023-07-28',
#   'kick_off': '11:30:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 865,
#    'home_team_name': "England Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 45,
#      'name': 'Sarina Glotzbach-Wiegman',
#      'nickname': 'Sarina Wiegman',
#      'dob': '1969-10-26',
#      'country': {'id': 160, 'name': 'Netherlands'}}]},
#   'away_team': {'away_team_id': 853,
#    'away_team_name': "Denmark Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 61, 'name': 'Denmark'},
#    'managers': [{'id': 3574,
#      'name': 'Lars Søndergaard',
#      'nickname': None,
#      'dob': '1959-04-05',
#      'country': {'id': 61, 'name': 'Denmark'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-13T20:58:07.431877',
#   'last_updated_360': '2023-08-13T21:04:12.717030',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 1001126,
#    'name': 'Allianz Stadium (Sydney)',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 830,
#    'name': 'Tess Olofsson',
#    'country': {'id': 220, 'name': 'Sweden'}}},
#  {'match_id': 3893812,
#   'match_date': '2023-07-28',
#   'kick_off': '03:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1204,
#    'home_team_name': "Argentina Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 11, 'name': 'Argentina'},
#    'managers': [{'id': 1003445,
#      'name': 'Germán Darío Portanova',
#      'nickname': None,
#      'dob': '1973-10-19',
#      'country': {'id': 11, 'name': 'Argentina'}}]},
#   'away_team': {'away_team_id': 1216,
#    'away_team_name': "South Africa Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 211, 'name': 'South Africa'},
#    'managers': [{'id': 3925,
#      'name': 'Desiree Ellis',
#      'nickname': None,
#      'dob': '1963-03-14',
#      'country': {'id': 211, 'name': 'South Africa'}}]},
#   'home_score': 2,
#   'away_score': 2,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-14T14:56:47.384447',
#   'last_updated_360': '2023-08-14T15:02:01.860096',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 1001341,
#    'name': 'Forsyth Barr',
#    'country': {'id': 163, 'name': 'New Zealand'}},
#   'referee': {'id': 2637,
#    'name': 'Anna-Marie Keighley',
#    'country': {'id': 163, 'name': 'New Zealand'}}},
#  {'match_id': 3893813,
#   'match_date': '2023-07-28',
#   'kick_off': '14:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1207,
#    'home_team_name': "China PR Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 46, 'name': 'China'},
#    'managers': [{'id': 1003429,
#      'name': 'Qingxia Shui',
#      'nickname': 'Shui Qingxia',
#      'dob': '1966-12-18',
#      'country': {'id': 46, 'name': 'China'}}]},
#   'away_team': {'away_team_id': 2355,
#    'away_team_name': "Haiti Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 98, 'name': 'Haiti'},
#    'managers': [{'id': 1003427,
#      'name': 'Nicolas Michel Gregory Delépine',
#      'nickname': None,
#      'dob': '1979-05-04',
#      'country': {'id': 78, 'name': 'France'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-03T04:23:35.957774',
#   'last_updated_360': '2023-08-03T04:25:06.499967',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 28889,
#    'name': 'Coopers Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 960,
#    'name': 'Marta Huerta de Aza',
#    'country': {'id': 214, 'name': 'Spain'}}},
#  {'match_id': 3893810,
#   'match_date': '2023-07-27',
#   'kick_off': '10:30:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 864,
#    'home_team_name': "Portugal Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 183, 'name': 'Portugal'},
#    'managers': [{'id': 419,
#      'name': 'Francisco Miguel Conceição Roque Neto',
#      'nickname': 'Francisco Neto',
#      'dob': '1981-07-11',
#      'country': {'id': 183, 'name': 'Portugal'}}]},
#   'away_team': {'away_team_id': 16769,
#    'away_team_name': "Vietnam Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 247, 'name': 'Vietnam'},
#    'managers': [{'id': 1003426,
#      'name': 'Đức Chung Mai',
#      'nickname': 'Mai Đức Chung',
#      'dob': '1951-06-21',
#      'country': {'id': 247, 'name': 'Vietnam'}}]},
#   'home_score': 2,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-18T14:28:14.691049',
#   'last_updated_360': '2023-08-18T14:30:26.614172',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 1001342,
#    'name': 'FMG Stadium Waikato',
#    'country': {'id': 163, 'name': 'New Zealand'}},
#   'referee': {'id': 2508,
#    'name': 'Salima Mukansanga',
#    'country': {'id': 189, 'name': 'Rwanda'}}},
#  {'match_id': 3893809,
#   'match_date': '2023-07-27',
#   'kick_off': '13:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1205,
#    'home_team_name': "Australia Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 14, 'name': 'Australia'},
#    'managers': [{'id': 408,
#      'name': 'Tony Gustavsson',
#      'nickname': None,
#      'dob': '1973-08-14',
#      'country': {'id': 220, 'name': 'Sweden'}}]},
#   'away_team': {'away_team_id': 1213,
#    'away_team_name': "Nigeria Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 166, 'name': 'Nigeria'},
#    'managers': [{'id': 1003417,
#      'name': 'Randy Marlon Waldrum',
#      'nickname': None,
#      'dob': '1956-09-25',
#      'country': {'id': 241, 'name': 'United States of America'}}]},
#   'home_score': 2,
#   'away_score': 3,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-18T14:04:52.791946',
#   'last_updated_360': '2023-08-18T14:06:33.469348',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 28884,
#    'name': 'Brisbane Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 723,
#    'name': 'Esther Staubli',
#    'country': {'id': 221, 'name': 'Switzerland'}}},
#  {'match_id': 3893807,
#   'match_date': '2023-07-26',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1206,
#    'home_team_name': "Canada Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 40, 'name': 'Canada'},
#    'managers': [{'id': 1000081,
#      'name': 'Beverly Priestman',
#      'nickname': None,
#      'dob': '1986-04-29',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 16768,
#    'away_team_name': "Republic of Ireland Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 109, 'name': 'Ireland'},
#    'managers': [{'id': 132,
#      'name': 'Vera Pauw',
#      'nickname': None,
#      'dob': '1963-01-18',
#      'country': {'id': 160, 'name': 'Netherlands'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-07-27T10:58:05.416876',
#   'last_updated_360': '2023-07-27T20:58:19.075800',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 28891,
#    'name': 'HBF Park',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 2601,
#    'name': 'Laura Fortunato',
#    'country': {'id': 11, 'name': 'Argentina'}}},
#  {'match_id': 3893804,
#   'match_date': '2023-07-25',
#   'kick_off': '11:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 860,
#    'home_team_name': "Switzerland Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 221, 'name': 'Switzerland'},
#    'managers': [{'id': 1002252,
#      'name': 'Inka Grings',
#      'nickname': None,
#      'dob': '1978-10-31',
#      'country': {'id': 85, 'name': 'Germany'}}]},
#   'away_team': {'away_team_id': 852,
#    'away_team_name': "Norway Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 171, 'name': 'Norway'},
#    'managers': [{'id': 1769,
#      'name': 'Hege Riise',
#      'nickname': None,
#      'dob': '1969-07-18',
#      'country': {'id': 171, 'name': 'Norway'}}]},
#   'home_score': 0,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-13T16:51:22.925450',
#   'last_updated_360': '2023-08-13T16:55:28.725897',
# ...
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 3,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 1001341,
#    'name': 'Forsyth Barr',
#    'country': {'id': 163, 'name': 'New Zealand'}},
#   'referee': {'id': 1171,
#    'name': 'Tori Penso',
#    'country': {'id': 241, 'name': 'United States of America'}}},
#  {'match_id': 3893816,
#   'match_date': '2023-07-29',
#   'kick_off': '15:30:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 16803,
#    'home_team_name': "Panama Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 176, 'name': 'Panama'},
#    'managers': [{'id': 1003446,
#      'name': 'Ignacio Quintana Toledo',
#      'nickname': None,
#      'dob': '1988-04-20',
#      'country': {'id': 147, 'name': 'Mexico'}}]},
#   'away_team': {'away_team_id': 1212,
#    'away_team_name': "Jamaica Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 113, 'name': 'Jamaica'},
#    'managers': [{'id': 1003439,
#      'name': 'Lorne Julian Donaldson',
#      'nickname': None,
#      'dob': '1986-10-09',
#      'country': {'id': 241, 'name': 'United States of America'}}]},
#   'home_score': 0,
#   'away_score': 1,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-21T14:28:43.104162',
#   'last_updated_360': '2023-08-21T14:33:06.577206',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 28891,
#    'name': 'HBF Park',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 374,
#    'name': 'Kateryna Monzul',
#    'country': {'id': 238, 'name': 'Ukraine'}}},
#  {'match_id': 3893815,
#   'match_date': '2023-07-29',
#   'kick_off': '13:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 861,
#    'home_team_name': "France Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 78, 'name': 'France'},
#    'managers': [{'id': 642,
#      'name': 'Hervé Renard',
#      'nickname': None,
#      'dob': '1968-09-30',
#      'country': {'id': 78, 'name': 'France'}}]},
#   'away_team': {'away_team_id': 1203,
#    'away_team_name': "Brazil Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 31, 'name': 'Brazil'},
#    'managers': [{'id': 177,
#      'name': 'Pia Mariane Sundhage',
#      'nickname': 'Pia Sundhage',
#      'dob': '1960-02-13',
#      'country': {'id': 220, 'name': 'Sweden'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-10T13:22:17.909730',
#   'last_updated_360': '2023-08-10T13:25:29.764380',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 28884,
#    'name': 'Brisbane Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 1640,
#    'name': 'Kate Jacewicz',
#    'country': {'id': 14, 'name': 'Australia'}}},
#  {'match_id': 3893805,
#   'match_date': '2023-07-26',
#   'kick_off': '08:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1210,
#    'home_team_name': "Japan Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 114, 'name': 'Japan'},
#    'managers': [{'id': 1003258,
#      'name': 'Futoshi Ikeda',
#      'nickname': None,
#      'dob': '1970-10-04',
#      'country': {'id': 114, 'name': 'Japan'}}]},
#   'away_team': {'away_team_id': 1832,
#    'away_team_name': "Costa Rica Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 54, 'name': 'Costa Rica'},
#    'managers': [{'id': 4855,
#      'name': 'Amelia Valverde',
#      'nickname': None,
#      'dob': '1987-01-14',
#      'country': {'id': 54, 'name': 'Costa Rica'}}]},
#   'home_score': 2,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-05T11:31:42.240459',
#   'last_updated_360': '2023-08-05T11:34:33.214164',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 1001341,
#    'name': 'Forsyth Barr',
#    'country': {'id': 163, 'name': 'New Zealand'}},
#   'referee': {'id': 1608,
#    'name': 'Maria Sole Ferrieri Caputi',
#    'country': {'id': 112, 'name': 'Italy'}}},
#  {'match_id': 3893803,
#   'match_date': '2023-07-25',
#   'kick_off': '08:30:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 1215,
#    'home_team_name': "New Zealand Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 163, 'name': 'New Zealand'},
#    'managers': [{'id': 1003415,
#      'name': 'Jitka Klimková',
#      'nickname': None,
#      'dob': '1974-08-20',
#      'country': {'id': 60, 'name': 'Czech Republic'}}]},
#   'away_team': {'away_team_id': 1106,
#    'away_team_name': "Philippines Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 180, 'name': 'Philippines'},
#    'managers': [{'id': 2957,
#      'name': 'Alen Stajčić',
#      'nickname': None,
#      'dob': '1973-11-02',
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 0,
#   'away_score': 1,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-21T13:04:19.101690',
#   'last_updated_360': '2023-08-21T13:08:15.309035',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 98115,
#    'name': 'Wellington Regional Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 1746,
#    'name': 'Katia Itzel García',
#    'country': {'id': 147, 'name': 'Mexico'}}},
#  {'match_id': 3893802,
#   'match_date': '2023-07-25',
#   'kick_off': '05:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 16802,
#    'home_team_name': "Colombia Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 49, 'name': 'Colombia'},
#    'managers': [{'id': 1003449,
#      'name': 'Angelo Marsiglia',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 49, 'name': 'Colombia'}}]},
#   'away_team': {'away_team_id': 1211,
#    'away_team_name': "Korea Republic Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 121, 'name': 'Korea\xa0(South)'},
#    'managers': [{'id': 585,
#      'name': 'Colin Bell',
#      'nickname': None,
#      'dob': '1961-08-05',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 2,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-14T12:24:32.484658',
#   'last_updated_360': '2023-08-14T12:28:53.852839',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 1,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 1001126,
#    'name': 'Allianz Stadium (Sydney)',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 566,
#    'name': 'Rebecca Welch',
#    'country': {'id': 68, 'name': 'England'}}},
#  {'match_id': 3893800,
#   'match_date': '2023-07-24',
#   'kick_off': '09:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 855,
#    'home_team_name': "Italy Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 112, 'name': 'Italy'},
#    'managers': [{'id': 4085,
#      'name': 'Milena Bertolini',
#      'nickname': None,
#      'dob': '1966-06-24',
#      'country': {'id': 112, 'name': 'Italy'}}]},
#   'away_team': {'away_team_id': 1204,
#    'away_team_name': "Argentina Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 11, 'name': 'Argentina'},
#    'managers': [{'id': 1003445,
#      'name': 'Germán Darío Portanova',
#      'nickname': None,
#      'dob': '1973-10-19',
#      'country': {'id': 11, 'name': 'Argentina'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-12T17:44:57.719395',
#   'last_updated_360': '2023-08-12T17:49:18.347307',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 1,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 28892,
#    'name': 'Eden Park',
#    'country': {'id': 163, 'name': 'New Zealand'}},
#   'referee': {'id': 1626,
#    'name': 'Melissa Paola Borjas Pastrana',
#    'country': {'id': 101, 'name': 'Honduras'}}},
#  {'match_id': 3893799,
#   'match_date': '2023-07-24',
#   'kick_off': '11:30:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 857,
#    'home_team_name': "Germany Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 85, 'name': 'Germany'},
#    'managers': [{'id': 53,
#      'name': 'Martina Voss-Tecklenburg',
#      'nickname': None,
#      'dob': '1967-12-22',
#      'country': {'id': 85, 'name': 'Germany'}}]},
#   'away_team': {'away_team_id': 2391,
#    'away_team_name': "Morocco Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 154, 'name': 'Morocco'},
#    'managers': [{'id': 760,
#      'name': 'Reynald Pedros',
#      'nickname': None,
#      'dob': '1971-10-10',
#      'country': {'id': 78, 'name': 'France'}}]},
#   'home_score': 6,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-21T14:27:48.144704',
#   'last_updated_360': '2023-08-21T14:33:45.142288',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 1,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 28886,
#    'name': 'AAMI Park',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 1171,
#    'name': 'Tori Penso',
#    'country': {'id': 241, 'name': 'United States of America'}}},
#  {'match_id': 3893796,
#   'match_date': '2023-07-23',
#   'kick_off': '08:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 858,
#    'home_team_name': "Sweden Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 220, 'name': 'Sweden'},
#    'managers': [{'id': 3016,
#      'name': 'Peter Gerhardsson',
#      'nickname': None,
#      'dob': '1959-08-22',
#      'country': {'id': 220, 'name': 'Sweden'}}]},
#   'away_team': {'away_team_id': 1216,
#    'away_team_name': "South Africa Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 211, 'name': 'South Africa'},
#    'managers': [{'id': 3925,
#      'name': 'Desiree Ellis',
#      'nickname': None,
#      'dob': '1963-03-14',
#      'country': {'id': 211, 'name': 'South Africa'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-07-30T08:04:59.799077',
#   'last_updated_360': '2023-07-30T08:06:34.006738',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 1,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 98115,
#    'name': 'Wellington Regional Stadium',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 751,
#    'name': 'Katja Koroleva',
#    'country': {'id': 241, 'name': 'United States of America'}}},
#  {'match_id': 3893795,
#   'match_date': '2023-07-22',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 853,
#    'home_team_name': "Denmark Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 61, 'name': 'Denmark'},
#    'managers': [{'id': 3574,
#      'name': 'Lars Søndergaard',
#      'nickname': None,
#      'dob': '1959-04-05',
#      'country': {'id': 61, 'name': 'Denmark'}}]},
#   'away_team': {'away_team_id': 1207,
#    'away_team_name': "China PR Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 46, 'name': 'China'},
#    'managers': [{'id': 1003429,
#      'name': 'Qingxia Shui',
#      'nickname': 'Shui Qingxia',
#      'dob': '1966-12-18',
#      'country': {'id': 46, 'name': 'China'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-16T06:04:10.017931',
#   'last_updated_360': '2023-08-16T06:06:04.857484',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 1,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 28891,
#    'name': 'HBF Park',
#    'country': {'id': 14, 'name': 'Australia'}},
#   'referee': {'id': 1627,
#    'name': 'Marie-Soleil Beaudoin',
#    'country': {'id': 40, 'name': 'Canada'}}},
#  {'match_id': 3893793,
#   'match_date': '2023-07-22',
#   'kick_off': '10:00:00.000',
#   'competition': {'competition_id': 72,
#    'country_name': 'International',
#    'competition_name': "Women's World Cup"},
#   'season': {'season_id': 107, 'season_name': '2023'},
#   'home_team': {'home_team_id': 6045,
#    'home_team_name': "Zambia Women's",
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 253, 'name': 'Zambia'},
#    'managers': [{'id': 1000425,
#      'name': 'Bruce Mwape',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 253, 'name': 'Zambia'}}]},
#   'away_team': {'away_team_id': 1210,
#    'away_team_name': "Japan Women's",
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 114, 'name': 'Japan'},
#    'managers': [{'id': 1003258,
#      'name': 'Futoshi Ikeda',
#      'nickname': None,
#      'dob': '1970-10-04',
#      'country': {'id': 114, 'name': 'Japan'}}]},
#   'home_score': 0,
#   'away_score': 5,
#   'match_status': 'available',
#   'match_status_360': 'available',
#   'last_updated': '2023-08-12T12:50:12.950377',
#   'last_updated_360': '2023-08-12T12:52:06.769558',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 1,
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'stadium': {'id': 1001342,
#    'name': 'FMG Stadium Waikato',
#    'country': {'id': 163, 'name': 'New Zealand'}},
#   'referee': {'id': 830,
#    'name': 'Tess Olofsson',
#    'country': {'id': 220, 'name': 'Sweden'}}}]

# %%
def get_teams(match_id):
    home = [match['home_team']['home_team_name'] for match in json_data_2023 if match['match_id'] == match_id][0]
    away = [match['away_team']['away_team_name'] for match in json_data_2023 if match['match_id'] == match_id][0]
    return home, away

# %%
Japan_matches_2023 = []
for item in json_data_2023:
    if item['home_team']['home_team_id'] == 1210:
        Japan_matches_2023.append(item['match_id'])
    if item['away_team']['away_team_id'] == 1210:
        Japan_matches_2023.append(item['match_id'])

# %%
url_WC_2019 = 'https://raw.githubusercontent.com/statsbomb/open-data/master/data/matches/72/30.json'
json_data_2019 = load_json(url_WC_2019)

# %%
Japan_matches_2019 = []
for item in json_data_2019:
    if item['home_team']['home_team_id'] == 1210:
        Japan_matches_2019.append(item['match_id'])
    if item['away_team']['away_team_id'] == 1210:
        Japan_matches_2019.append(item['match_id'])

# %%
position_dict = {1:(10, 40), 
                 2:(25, 72), 3:(25, 56), 4:(25, 40), 5:(25, 24), 6:(25, 8),
                 7:(42.5, 72), 9:(42.5, 56), 10:(42.5, 40), 11:(42.5, 24), 8:(42.5, 8),
                 12:(60, 72), 13:(60, 56), 14:(60, 40), 15:(60, 24), 16:(60, 8),
                 17:(77.5, 72), 18:(77.5, 56), 19:(77.5, 40), 20:(77.5, 24), 21:(77.5, 8),
                 25:(88.75, 40), 22:(100, 56), 23:(100, 40), 24:(100, 24)}

# %%
def plot_match(match_id, team_nation, opponent_nation):
    url = f'https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/{match_id}.json'
    match_events = load_json(url)
    team = f"{team_nation} Women's"
    opponent = f"{opponent_nation} Women's" 
    
    starting_XI = [event for event in match_events if event['team']['name'] == team and event['type']['id'] == 35]
    position_ids = [player['position']['id'] for player in starting_XI[0]['tactics']['lineup']]
    
    tactic_XI = [event for event in match_events if event['team']['name'] == team and event['type']['id'] == 36]
    
    team_events = [event for event in match_events if event['team']['name'] == team]
    
    goal_events = [event for event in match_events if event['type']['id'] == 16 and 
            event['team']['name'] == team and event['shot']['outcome']['name'] == 'Goal']
    no_goal_events = [event for event in match_events if event['type']['id'] == 16 and 
            event['team']['name'] == team and event['shot']['outcome']['name'] != 'Goal']
    
    oppo_goal_events = [event for event in match_events if event['type']['id'] == 16 and 
            event['team']['name'] == opponent and event['shot']['outcome']['name'] == 'Goal']
    oppo_no_goal_events = [event for event in match_events if event['type']['id'] == 16 and 
            event['team']['name'] == opponent and event['shot']['outcome']['name'] != 'Goal']
    
    goal_seq = {}
    for event in goal_events:
        before_goal_events = team_events[team_events.index(event) - 4:team_events.index(event)+1]
        before_goal_events= [e for e in before_goal_events if 'location' in e]
        goal_seq[event['index']] = before_goal_events
        
    no_goal_seq = {}
    for event in no_goal_events:
        before_no_goal_events = team_events[team_events.index(event) - 4:team_events.index(event)+1]
        before_no_goal_events= [e for e in before_no_goal_events if 'location' in e]
        no_goal_seq[event['index']] = before_no_goal_events
    
    team_carry = [event for event in match_events if event['type']['id'] == 43 and
                event['team']['name'] == team and event['duration'] > 3.5]        
            
    dispo_events = [event for event in match_events if event['team']['name'] == opponent and
               event['type']['id'] == 3]
    
    opponent_carry = [event for event in match_events if event['type']['id'] == 43 and
                event['team']['name'] == opponent and event['duration'] > 3.5]
        
    field_layout = soccerfield.get_layout()
    field_layout.update(legend=dict(x=0.85, y=1))

    fig = go.Figure(layout=field_layout)
    fig.update_layout(title = dict(text = f'{team} vs {opponent}', x =0.5, y =0.9), 
                      title_font=dict(size=20, family='Arial', color='black'))

    # Starting lineups
    fig.add_trace(go.Scatter(
        x = [position_dict[i][0] for i in position_ids],
        y = [position_dict[i][1] for i in position_ids],
        mode='markers',
        name = 'starting XI',
        marker=dict(size=8, symbol = 'circle', color='lightblue',
            line = dict(width = 1, color = 'darkblue')),
    ))
    
    # Tactical shifts
    if len(tactic_XI) != 0:
        for tac in tactic_XI:
            time = str(tac['minute']) + ':' + str(tac['second'])
            tac_ids = [player['position']['id'] for player in tac['tactics']['lineup']]
            if tac_ids != position_ids:
                fig.add_trace(go.Scatter(
                    x = [position_dict[i][0] for i in tac_ids],
                    y = [position_dict[i][1] for i in tac_ids],
                    mode='markers',
                    name = f'tactical shit - {time}',
                    marker=dict(size=8, symbol = 'circle', color='lightblue', opacity=0.5,
                        line = dict(width = 1, color = 'steelblue')),
                    showlegend = True, visible='legendonly'
                ))

    # Shot with no goal - team
    fig.add_trace(go.Scatter(
        x = [event['location'][0] for event in no_goal_events],
        y = [event['location'][1] for event in no_goal_events],
        legendgroup = 'no goal shots',
        name = 'team shot w/ no goal',
        mode='markers',
        marker=dict(size=5, symbol = 'circle', color='darkgoldenrod')
    ))

    # Shot with goals - team
    fig.add_trace(go.Scatter(
        x = [event['location'][0] for event in goal_events],
        y = [event['location'][1] for event in goal_events],
        legendgroup = 'goal shots',
        name = 'team shot w/ goal',
        mode='markers',
        marker=dict(size=6, symbol = 'circle', color='purple')
    ))

    # Shot with no goal - oppo
    fig.add_trace(go.Scatter(
        x = [120-event['location'][0] for event in no_goal_events],
        y = [event['location'][1] for event in no_goal_events],
        legendgroup = 'oppo no goal shots', visible='legendonly',
        name = 'opponent shot w/ no goal',
        mode='markers',
        marker=dict(size=5, symbol = 'circle', color='darkgoldenrod')
    ))
    
    # Shot with goals - oppo
    fig.add_trace(go.Scatter(
        x = [120-event['location'][0] for event in oppo_goal_events],
        y = [event['location'][1] for event in oppo_goal_events],
        legendgroup = 'oppo goal shots', visible='legendonly',
        name = 'opponent shot w/ goal',
        mode='markers',
        marker=dict(size=6, symbol = 'circle', color='purple')
    ))

    # Moves before shot with goals
    for key, seq in goal_seq.items():
        fig.add_trace(go.Scatter(
            x = [event['location'][0] for event in seq[:-1]],
            y = [event['location'][1] for event in seq[:-1]],
            legendgroup = 'goal shots',
            showlegend = False,
            mode='markers',
            marker=dict( size=6, symbol = 'circle', color='purple', opacity=0.3)
        ))
    for key, seq in goal_seq.items():
        fig.add_trace(go.Scatter(
            x=[event['location'][0] for event in seq],  
            y=[event['location'][1] for event in seq], 
            legendgroup = 'goal shots',
            showlegend = False,
            mode='lines',
            line=dict(color='purple', width = 0.25)
        ))

    # Moves before shot with no goal
    for key, seq in no_goal_seq.items():
        fig.add_trace(go.Scatter(
            x = [event['location'][0] for event in seq[:-1]],
            y = [event['location'][1] for event in seq[:-1]],
            legendgroup = 'no goal shots',
            showlegend = False,
            mode='markers',
            marker=dict( size=5, symbol = 'circle', color='tan', opacity=0.3)
        ))
    for key, seq in no_goal_seq.items():
        fig.add_trace(go.Scatter(
            x=[event['location'][0] for event in seq],  
            y=[event['location'][1] for event in seq], 
            legendgroup = 'no goal shots',
            showlegend = False,
            mode='lines',
            line=dict(color='tan', width = 0.18)
        ))    

    # Opponent disposession
    fig.add_trace(go.Scatter(
        x = [120-event['location'][0] for event in dispo_events],
        y = [event['location'][1] for event in dispo_events],
        name = 'opponent disposession',
        mode='markers',
        marker=dict(size=6, symbol = 'x', color='darkseagreen', opacity=0.6)
    ))
    
    # Team carry
    fig.add_trace(go.Scatter(x = [None], y = [None], legendgroup = 'team_carry', name = 'team_carry',
                            mode='lines', line=dict(color='orchid', width = 0.4, dash = 'dash'), visible='legendonly'))
    
    for carry in team_carry:
        fig.add_trace(go.Scatter(
            x = [carry['location'][0], carry['carry']['end_location'][0]],
            y = [carry['location'][1], carry['carry']['end_location'][1]],
            legendgroup = 'team_carry',
            showlegend = False, visible='legendonly',
            mode='lines',
            line=dict(color='orchid', width = 0.3, dash = 'dash')
        ))    
        
    # Opponent carry
    fig.add_trace(go.Scatter(x = [None], y = [None], legendgroup = 'opponent_carry', name = 'opponent_carry',
                            mode='lines', line=dict(color='darkgrey', width = 0.4, dash = 'dash')))
    
    for carry in opponent_carry:
        fig.add_trace(go.Scatter(
            x = [120-carry['location'][0], 120-carry['carry']['end_location'][0]],
            y = [carry['location'][1], carry['carry']['end_location'][1]],
            legendgroup = 'opponent_carry',
            showlegend = False,
            mode='lines',
            line=dict(color='darkgrey', width = 0.3, dash = 'dash')
        ))

    fig.show()

# %%
for match in Japan_matches_2023:
    print(match)
    home, away = get_teams(match)
    print(home+ ' vs '+away)
# Out:
# 3893822
# Japan Women's vs Spain Women's
# 3902239
# Japan Women's vs Sweden Women's
# 3901734
# Japan Women's vs Norway Women's
# 3893805
# Japan Women's vs Costa Rica Women's
# 3893793
# Zambia Women's vs Japan Women's

# %%
plot_match(3893822, 'Japan', 'Spain')
# Out:
# <div>                            <div id="81853425-6e78-45a6-888b-d65ea557e527" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81853425-6e78-45a6-888b-d65ea557e527")) {                    Plotly.newPlot(                        "81853425-6e78-45a6-888b-d65ea557e527",                        [{"marker":{"color":"lightblue","line":{"color":"darkblue","width":1},"size":8,"symbol":"circle"},"mode":"markers","name":"starting XI","x":[10,25,25,25,42.5,42.5,42.5,42.5,77.5,77.5,100],"y":[40,56,40,24,72,8,56,24,56,24,40],"type":"scatter"},{"legendgroup":"goal shots","marker":{"color":"purple","size":6,"symbol":"circle"},"mode":"markers","name":"team shot w/ goal","x":[107.4,106.0,106.2,107.1],"y":[37.8,28.5,47.6,48.5],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"darkgoldenrod","size":5,"symbol":"circle"},"mode":"markers","name":"team shot w/ no goal","x":[90.1,108.6,92.8],"y":[45.4,44.6,30.3],"type":"scatter"},{"legendgroup":"oppo goal shots","marker":{"color":"purple","size":6,"symbol":"circle"},"mode":"markers","name":"opponent shot w/ goal","visible":"legendonly","x":[],"y":[],"type":"scatter"},{"legendgroup":"oppo no goal shots","marker":{"color":"darkgoldenrod","size":5,"symbol":"circle"},"mode":"markers","name":"opponent shot w/ no goal","visible":"legendonly","x":[29.900000000000006,11.400000000000006,27.200000000000003],"y":[45.4,44.6,30.3],"type":"scatter"},{"legendgroup":"goal shots","marker":{"color":"purple","opacity":0.3,"size":6,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[64.3,70.6,98.5,98.5],"y":[7.3,8.4,40.4,40.4],"type":"scatter"},{"legendgroup":"goal shots","marker":{"color":"purple","opacity":0.3,"size":6,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[55.9,75.1,99.4,99.4],"y":[47.3,48.3,29.0,29.0],"type":"scatter"},{"legendgroup":"goal shots","marker":{"color":"purple","opacity":0.3,"size":6,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[57.9,74.5,92.6,92.6],"y":[41.1,45.5,55.9,55.9],"type":"scatter"},{"legendgroup":"goal shots","marker":{"color":"purple","opacity":0.3,"size":6,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[38.6,43.5,85.2,85.2],"y":[57.9,80.0,75.0,75.0],"type":"scatter"},{"legendgroup":"goal shots","line":{"color":"purple","width":0.25},"mode":"lines","showlegend":false,"x":[64.3,70.6,98.5,98.5,107.4],"y":[7.3,8.4,40.4,40.4,37.8],"type":"scatter"},{"legendgroup":"goal shots","line":{"color":"purple","width":0.25},"mode":"lines","showlegend":false,"x":[55.9,75.1,99.4,99.4,106.0],"y":[47.3,48.3,29.0,29.0,28.5],"type":"scatter"},{"legendgroup":"goal shots","line":{"color":"purple","width":0.25},"mode":"lines","showlegend":false,"x":[57.9,74.5,92.6,92.6,106.2],"y":[41.1,45.5,55.9,55.9,47.6],"type":"scatter"},{"legendgroup":"goal shots","line":{"color":"purple","width":0.25},"mode":"lines","showlegend":false,"x":[38.6,43.5,85.2,85.2,107.1],"y":[57.9,80.0,75.0,75.0,48.5],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[108.9,107.4,107.9,88.2],"y":[54.3,46.8,45.9,45.5],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[110.4,110.4,112.4,108.6],"y":[65.2,65.2,65.4,44.6],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[112.1,116.8,78.9,90.5],"y":[80.0,57.9,29.4,25.8],"type":"scatter"},{"legendgroup":"no goal shots","line":{"color":"tan","width":0.18},"mode":"lines","showlegend":false,"x":[108.9,107.4,107.9,88.2,90.1],"y":[54.3,46.8,45.9,45.5,45.4],"type":"scatter"},{"legendgroup":"no go ...

# %%
plot_match(3893822, 'Spain', 'Japan')
# Out:
# <div>                            <div id="a3b611f0-8f53-42fb-9981-4c8d9ed66480" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3b611f0-8f53-42fb-9981-4c8d9ed66480")) {                    Plotly.newPlot(                        "a3b611f0-8f53-42fb-9981-4c8d9ed66480",                        [{"marker":{"color":"lightblue","line":{"color":"darkblue","width":1},"size":8,"symbol":"circle"},"mode":"markers","name":"starting XI","x":[10,25,25,25
6],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[86.3,87.7,106.8,106.8],"y":[43.1,35.7,24.7,24.7],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[106.8,106.8,107.8,116.6],"y":[24.7,24.7,28.1,46.6],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[86.7,97.1,100.2,98.3],"y":[49.4,48.8,38.7,27.6],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[115.2,115.2,117.6,111.9],"y":[12.3,12.3,11.7,35.5],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[98.8,98.8,104.9,106.8],"y":[47.1,47.1,50.1,52.3],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[105.7,107.5,107.9,106.8],"y":[23.8,23.1,23.1,27.0],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[101.8,101.8,103.8,107.9],"y":[14.1,14.1,13.0,36.6],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"co ...

# %%
plot_match(3893793, 'Japan', 'Zambia')
# Out:
# <div>                            <div id="bf12494b-069f-48ed-b131-15f564c664cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf12494b-069f-48ed-b131-15f564c664cd")) {                    Plotly.newPlot(                        "bf12494b-069f-48ed-b131-15f564c664cd",                        [{"marker":{"color":"lightblue","line":{"color":"darkblue","width":1},"size":8,"symbol":"circle"},"mode":"markers","name":"starting XI","x":[10,25,25,25,42.5,42.5,42.5,42.5,77.5,77.5,100],"y":[40,56,40,24,72,8,56,24,72,8,40],"type":"scatter"},{"legendgroup":"goal shots","marker":{"color":"purple","size":6,"symbol":"circle"},"mode":"markers","name":"goal","x":[107.1,112.8,113.5,111.2,108.1],"y":[44.7,38.4,42.8,31.1,40.1],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"darkgoldenrod","size":5,"symbol":"circle"},"mode":"markers","name":"no goal","x":[107.4,108.3,88.4,90.7,113.0,101.7,108.0,92.9,110.2,115.1,100.8,114.0,106.6,108.8,113.1,106.8,110.5,113.3,107.4,107.4,112.2],"y":[27.2,46.6,40.8,24.5,37.6,25.0,52.0,40.3,30.4,49.2,67.2,27.6,42.5,43.0,40.3,49.6,27.4,32.0,23.6,61.0,45.5],"type":"scatter"},{"legendgroup":"goal shots","marker":{"color":"purple","opacity":0.3,"size":6,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[87.4,87.4,99.9,107.1],"y":[76.2,76.2,70.9,44.7],"type":"scatter"},{"legendgroup":"goal shots","marker":{"color":"purple","opacity":0.3,"size":6,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[110.7,110.7,112.8,112.8],"y":[23.2,23.2,38.4,38.4],"type":"scatter"},{"legendgroup":"goal shots","marker":{"color":"purple","opacity":0.3,"size":6,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[116.7,116.7,117.9,113.5],"y":[69.7,69.7,69.0,42.8],"type":"scatter"},{"legendgroup":"goal shots","marker":{"color":"purple","opacity":0.3,"size":6,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[82.4,81.6,97.2,97.2],"y":[55.3,46.7,24.0,24.0],"type":"scatter"},{"legendgroup":"goal shots","marker":{"color":"purple","opacity":0.3,"size":6,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[69.0,102.8,102.8,104.3],"y":[57.1,52.0,52.0,52.5],"type":"scatter"},{"legendgroup":"goal shots","line":{"color":"purple","width":0.25},"mode":"lines","showlegend":false,"x":[87.4,87.4,99.9,107.1,107.1],"y":[76.2,76.2,70.9,44.7,44.7],"type":"scatter"},{"legendgroup":"goal shots","line":{"color":"purple","width":0.25},"mode":"lines","showlegend":false,"x":[110.7,110.7,112.8,112.8,112.8],"y":[23.2,23.2,38.4,38.4,38.4],"type":"scatter"},{"legendgroup":"goal shots","line":{"color":"purple","width":0.25},"mode":"lines","showlegend":false,"x":[116.7,116.7,117.9,113.5,113.5],"y":[69.7,69.7,69.0,42.8,42.8],"type":"scatter"},{"legendgroup":"goal shots","line":{"color":"purple","width":0.25},"mode":"lines","showlegend":false,"x":[82.4,81.6,97.2,97.2,111.2],"y":[55.3,46.7,24.0,24.0,31.1],"type":"scatter"},{"legendgroup":"goal shots","line":{"color":"purple","width":0.25},"mode":"lines","showlegend":false,"x":[69.0,102.8,102.8,104.3,108.1],"y":[57.1,52.0,52.0,52.5,40.1],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[68.7,85.7,85.7,107.4],"y":[30.9,29.6,29.6,27.2],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[110.6,111.4,110.4,110.4],"y":[55.8,55.8,42.5,42.5],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"symbol":"circle"},"mode":"markers","showlegend":false,"x":[78.0,76.3,84.4,84.4],"y":[10.1,11.8,34.9,34.9],"type":"scatter"},{"legendgroup":"no goal shots","marker":{"color":"tan","opacity":0.3,"size":5,"s ...

# %%
Japan_matches_2022 = []
for item in json_data_2022:
    if item['home_team']['home_team_id'] == 778:
        Japan_matches_2022.append(item['match_id'])
    if item['away_team']['away_team_id'] == 778:
        Japan_matches_2022.append(item['match_id'])

# %%
for match_id in Japan_matches_2022:
    print(match_id)
    home = [match['home_team']['home_team_name'] for match in json_data_2022 if match['match_id'] == match_id][0]
    away = [match['away_team']['away_team_name'] for match in json_data_2022 if match['match_id'] == match_id][0]
    print(home, away)
# Out:
# 3869219
# Japan Croatia
# 3857295
# Japan Costa Rica
# 3857284
# Germany Japan
# 3857255
# Japan Spain

# %%
url = f'https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/3857255.json'
match_events = load_json(url)

# %%
team = 'Japan'

# %%
starting_XI = [event for event in match_events if event['team']['name'] == team and event['type']['id'] == 35]
position_ids = [player['position']['id'] for player in starting_XI[0]['tactics']['lineup']]

# %%
tactic_XI = [event for event in match_events if event['team']['name'] == team and event['type']['id'] == 36]

# %%
team_events = [event for event in match_events if event['team']['name'] == team]

# %%
goal_events = [event for event in match_events if event['type']['id'] == 16 and 
        event['team']['name'] == team and event['shot']['outcome']['name'] == 'Goal']
no_goal_events = [event for event in match_events if event['type']['id'] == 16 and 
        event['team']['name'] == team and event['shot']['outcome']['name'] != 'Goal']

# %%
goal_events
# Out:
# [{'id': '7a8d09b4-e1da-4112-a8fc-6784cf2029a4',
#   'index': 2476,
#   'period': 2,
#   'timestamp': '00:02:48.337',
#   'minute': 47,
#   'second': 48,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 68,
#   'possession_team': {'id': 778, 'name': 'Japan'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 778, 'name': 'Japan'},
#   'player': {'id': 8361, 'name': 'Ritsu Doan'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [100.5, 55.8],
#   'duration': 0.80211,
#   'related_events': ['31357970-dd9e-4523-a4d1-d3d354959e88'],
#   'shot': {'statsbomb_xg': 0.027777622,
#    'end_location': [120.0, 42.2, 1.9],
#    'key_pass_id': 'f72a9178-aca5-41f9-8dc9-1a518332e5ec',
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'outcome': {'id': 97, 'name': 'Goal'},
#    'technique': {'id': 93, 'name': 'Normal'},
#    'freeze_frame': [{'location': [107.5, 54.3],
#      'player': {'id': 30628, 'name': 'Daizen Maeda'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [118.0, 42.1],
#      'player': {'id': 11748, 'name': 'Unai Simón Mendibil'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [101.3, 59.3],
#      'player': {'id': 39161, 'name': 'Alejandro Balde Martínez'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [92.5, 28.6],
#      'player': {'id': 133353, 'name': 'Pablo Martín Páez Gavira'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': False},
#     {'location': [104.0, 58.2],
#      'player': {'id': 30486, 'name': 'Pedro González López'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': False},
#     {'location': [105.5, 49.8],
#      'player': {'id': 5203, 'name': 'Sergio Busquets i Burgos'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': False},
#     {'location': [106.6, 52.5],
#      'player': {'id': 6892, 'name': 'Pau Francisco Torres'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [108.6, 39.0],
#      'player': {'id': 6765, 'name': 'Rodrigo Hernández Cascante'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [104.5, 29.5],
#      'player': {'id': 5721, 'name': 'Daniel Carvajal Ramos'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [97.1, 68.2],
#      'player': {'id': 23527, 'name': 'Junya Ito'},
#      'position': {'id': 7, 'name': 'Right Wing Back'},
#      'teammate': True},
#     {'location': [99.4, 58.7],
#      'player': {'id': 37221, 'name': 'Hidemasa Morita'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': True},
#     {'location': [93.9, 33.0],
#      'player': {'id': 37208, 'name': 'Ao Tanaka'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': True},
#     {'location': [95.5, 31.2],
#      'player': {'id': 37211, 'name': 'Kaoru Mitoma'},
#      'position': {'id': 8, 'name': 'Left Wing Back'},
#      'teammate': True},
#     {'location': [104.5, 35.4],
#      'player': {'id': 9411, 'name': 'Daichi Kamada'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True}]}},
#  {'id': 'f7164861-b772-4dfb-96d7-37e3ec5bfefd',
#   'index': 2510,
#   'period': 2,
#   'timestamp': '00:05:14.187',
#   'minute': 50,
#   'second': 14,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 71,
#   'possession_team': {'id': 778, 'name': 'Japan'},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 778, 'name': 'Japan'},
#   'player': {'id': 37208, 'name': 'Ao Tanaka'},
#   'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#   'location': [118.7, 40.2],
#   'duration': 0.352541,
#   'related_events': ['9d3f90c0-cb5b-43ed-b9ba-410229cdd9c5'],
#   'shot': {'open_goal': True,
#    'statsbomb_xg': 0.87261814,
#    'end_location': [120.0, 40.6, 1.8],
#    'key_pass_id': '82cb8853-47f7-4bf7-ac52-8952926e6c3f',
#    'technique': {'id': 93, 'name': 'Normal'},
#    'body_part': {'id': 70, 'name': 'Other'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'outcome': {'id': 97, 'name': 'Goal'},
#    'freeze_frame': [{'location': [120.0, 37.6],
#      'player': {'id': 11748, 'name': 'Unai Simón Mendibil'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [110.6, 63.9],
#      'player': {'id': 8361, 'name': 'Ritsu Doan'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [108.9, 50.0],
#      'player': {'id': 23527, 'name': 'Junya Ito'},
#      'position': {'id': 7, 'name': 'Right Wing Back'},
#      'teammate': True},
#     {'location': [110.3, 36.7],
#      'player': {'id': 9411, 'name': 'Daichi Kamada'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [110.3, 54.7],
#      'player': {'id': 30486, 'name': 'Pedro González López'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': False},
#     {'location': [112.5, 55.5],
#      'player': {'id': 39161, 'name': 'Alejandro Balde Martínez'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [104.2, 36.1],
#      'player': {'id': 68574, 'name': 'Nicholas Williams Arthuer'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': False},
#     {'location': [108.1, 39.5],
#      'player': {'id': 133353, 'name': 'Pablo Martín Páez Gavira'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': False},
#     {'location': [114.6, 48.2],
#      'player': {'id': 6892, 'name': 'Pau Francisco Torres'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [111.7, 41.7],
#      'player': {'id': 5203, 'name': 'Sergio Busquets i Burgos'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': False},
#     {'location': [118.1, 39.4],
#      'player': {'id': 6765, 'name': 'Rodrigo Hernández Cascante'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [120.0, 33.9],
#      'player': {'id': 5721, 'name': 'Daniel Carvajal Ramos'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [120.0, 34.8],
#      'player': {'id': 30628, 'name': 'Daizen Maeda'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [120.0, 32.8],
#      'player': {'id': 37211, 'name': 'Kaoru Mitoma'},
#      'position': {'id': 8, 'name': 'Left Wing Back'},
#      'teammate': True}]}}]

# %%
def plot_match_m(match_id, team, opponent):
    url = f'https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/{match_id}.json'
    match_events = load_json(url)
    starting_XI = [event for event in match_events if event['team']['name'] == team and event['type']['id'] == 35]
    position_ids = [player['position']['id'] for player in starting_XI[0]['tactics']['lineup']]

    tactic_XI = [event for event in match_events if event['team']['name'] == team and event['type']['id'] == 36]

    team_events = [event for event in match_events if event['team']['name'] == team]

    goal_events = [event for event in match_events if event['type']['id'] == 16 and 
            event['team']['name'] == team and event['shot']['outcome']['name'] == 'Goal']
    no_goal_events = [event for event in match_events if event['type']['id'] == 16 and 
            event['team']['name'] == team and event['shot']['outcome']['name'] != 'Goal']

    goal_seq = {}
    for event in goal_events:
        before_goal_events = team_events[team_events.index(event) - 4:team_events.index(event)+1]
        before_goal_events= [e for e in before_goal_events if 'location' in e]
        goal_seq[event['index']] = before_goal_events

    no_goal_seq = {}
    for event in no_goal_events:
        before_no_goal_events = team_events[team_events.index(event) - 4:team_events.index(event)+1]
        before_no_goal_events= [e for e in before_no_goal_events if 'location' in e]
        no_goal_seq[event['index']] = before_no_goal_events

    dispo_events = [event for event in match_events if event['team']['name'] == opponent and
               event['type']['id'] == 3]

    field_layout = soccerfield.get_layout()
    field_layout.update(legend=dict(x=0.85, y=1))

    fig = go.Figure(layout=field_layout)
    fig.update_layout(title = dict(text = f"{team} Men's vs {opponent} Men's", x =0.5, y =0.9), 
                      title_font=dict(size=20, family='Arial', color='black'))

    # Starting lineups
    fig.add_trace(go.Scatter(
        x = [position_dict[i][0] for i in position_ids],
        y = [position_dict[i][1] for i in position_ids],
        mode='markers',
        name = 'starting XI',
        marker=dict(size=8, symbol = 'circle', color='lightblue',
            line = dict(width = 1, color = 'darkblue')),
    ))

    # Tactical shifts
    if len(tactic_XI) != 0:
        for tac in tactic_XI:
            time = str(tac['minute']) + ':' + str(tac['second'])
            tac_ids = [player['position']['id'] for player in tac['tactics']['lineup']]
            if tac_ids != position_ids:
                fig.add_trace(go.Scatter(
                    x = [position_dict[i][0] for i in tac_ids],
                    y = [position_dict[i][1] for i in tac_ids],
                    mode='markers',
                    name = f'tactical shit - {time}',
                    marker=dict(size=8, symbol = 'circle', color='lightblue', opacity=0.5,
                        line = dict(width = 1, color = 'steelblue')),
                    showlegend = True, visible='legendonly'
                ))

    # Shot with goals
    fig.add_trace(go.Scatter(
        x = [event['location'][0] for event in goal_events],
        y = [event['location'][1] for event in goal_events],
        legendgroup = 'goal shots',
        name = 'goal',
        mode='markers',
        marker=dict(size=6, symbol = 'circle', color='purple')
    ))

    # Shot with no goal
    fig.add_trace(go.Scatter(
        x = [event['location'][0] for event in no_goal_events],
        y = [event['location'][1] for event in no_goal_events],
        legendgroup = 'no goal shots',
        name = 'no goal',
        mode='markers',
        marker=dict(size=5, symbol = 'circle', color='darkgoldenrod')
    ))

    # Moves before shot with goals
    for key, seq in goal_seq.items():
        fig.add_trace(go.Scatter(
            x = [event['location'][0] for event in seq[:-1]],
            y = [event['location'][1] for event in seq[:-1]],
            legendgroup = 'goal shots',
            showlegend = False,
            mode='markers',
            marker=dict( size=6, symbol = 'circle', color='purple', opacity=0.3)
        ))
    for key, seq in goal_seq.items():
        fig.add_trace(go.Scatter(
            x=[event['location'][0] for event in seq],  
            y=[event['location'][1] for event in seq], 
            legendgroup = 'goal shots',
            showlegend = False,
            mode='lines',
            line=dict(color='purple', width = 0.25)
        ))

    # Moves before shot with no goal
    for key, seq in no_goal_seq.items():
        fig.add_trace(go.Scatter(
            x = [event['location'][0] for event in seq[:-1]],
            y = [event['location'][1] for event in seq[:-1]],
            legendgroup = 'no goal shots',
            showlegend = False,
            mode='markers',
            marker=dict( size=5, symbol = 'circle', color='tan', opacity=0.3)
        ))
    for key, seq in no_goal_seq.items():
        fig.add_trace(go.Scatter(
            x=[event['location'][0] for event in seq],  
            y=[event['location'][1] for event in seq], 
            legendgroup = 'no goal shots',
            showlegend = False,
            mode='lines',
            line=dict(color='tan', width = 0.18)
        ))    

    # Opponent disposession
    fig.add_trace(go.Scatter(
        x = [120-event['location'][0] for event in dispo_events],
        y = [event['location'][1] for event in dispo_events],
        name = 'opponent disposession',
        mode='markers',
        marker=dict(size=6, symbol = 'x', color='darkseagreen', opacity=0.6)
    ))

    fig.show()

# %%
plot_match_m(3857255, 'Japan', 'Spain')
# Out:
# <div>                            <div id="0a43523e-5eb1-41b3-b51b-22afcb466722" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0